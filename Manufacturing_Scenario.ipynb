# %% [markdown]
# # Smart Queue Monitoring System - Manufacturing Scenario
#
# ## Overview
# Now that you have your Python script and job submission script, you're ready to request an **IEI Tank-870** edge node and run inference on the different hardware types (CPU, GPU, VPU, FPGA).
#
# After the inference is completed, the output video and stats files need to be retrieved and stored in the workspace, which can then be viewed within the Jupyter Notebook.
#
# ## Objectives
# * Submit inference jobs to Intel's DevCloud using the `qsub` command.
# * Retrieve and review the results.
# * After testing, go back to the proposal doc and update your original proposed hardware device.

# %% [markdown]
# ## Step 0: Set Up
#
# #### IMPORTANT: Set up paths so we can run Dev Cloud utilities
# You *must* run this every time you enter a Workspace session.
# (Tip: select the cell and use **Shift+Enter** to run the cell.)

# %%
# %env PATH=/opt/conda/bin:/opt/spark-2.4.3-bin-hadoop2.7/bin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/intel_devcloud_support
import os
import sys
sys.path.insert(0, os.path.abspath('/opt/intel_devcloud_support'))
sys.path.insert(0, os.path.abspath('/opt/intel'))
# Out:
# env: PATH=/opt/conda/bin:/opt/spark-2.4.3-bin-hadoop2.7/bin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/intel_devcloud_support

# %%
! ls
# Out:
# config_git.txt			    queue_job.sh
# Create_Job_Submission_Script.ipynb  results
# Create_Python_Script.ipynb	    Retail_Scenario.ipynb
# Manufacturing_Scenario.ipynb	    stderr.log
# original_videos			    stdout.log
# output.tgz			    Transportation_Scenario.ipynb
# person_detect.py

# %% [markdown]
# ### Step 0.1:  (Optional-step): Original Video
#
# If you are curious to see the input video, run the following cell to view the original video stream we'll be using for inference.

# %%
import videoHtml
videoHtml.videoHTML('Manufacturing', ['original_videos/Manufacturing.mp4'])
# Out:
# <h5>Manufacturing</h5>
#         <video alt="" controls autoplay muted height="480"><source src="original_videos/Manufacturing.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1 : Inference on a Video
#
# In the next few cells, You'll submit your job using the `qsub` command and retrieve the results for each job. Each of the cells below should submit a job to different edge compute nodes.
#
# The output of the cell is the `JobID` of your job, which you can use to track progress of a job with `liveQStat`.
#
# You will need to submit a job for each of the following hardware types:
# * **CPU**
# * **GPU**
# * **VPU**
# * **FPGA**
#
# **Note:** You will have to submit each job one at a time and retrieve their results.
#
# After submission, they will go into a queue and run as soon as the requested compute resources become available.
# (Tip: **shift+enter** will run the cell and automatically move you to the next cell.)
#
# If your job successfully runs and completes, once you retrieve your results, it should output a video and a stats text file in the `results/manufacturing/<DEVICE>` directory.
#
# For example, your **CPU** job should output its files in this directory:
# > **results/manufacturing/cpu**
#
# **Note**: To get the queue labels for the different hardware devices, you can go to [this link](https://devcloud.intel.com/edge/get_started/devcloud/).
#
# The following arguments should be passed to the job submission script after the `-F` flag:
# * Model path - `/data/models/intel/person-detection-retail-0013/<MODEL PRECISION>/`. You will need to adjust this path based on the model precision being using on the hardware.
# * Device - `CPU`, `GPU`, `MYRIAD`, `HETERO:FPGA,CPU`.
# * Manufacturing video path - `/data/resources/manufacturing.mp4`.
# * Manufacturing queue_param file path - `/data/queue_param/manufacturing.npy`.
# * Output path - `/output/results/manufacturing/<DEVICE>` This should be adjusted based on the device used in the job.
# * Max num of people - This is the max number of people in queue before the system would redirect them to another queue.

# %% [markdown]
# ## Step 1.1: Submit to an Edge Compute Node with an Intel CPU
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank* 870-Q170</a> edge node with an <a
#     href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel Core™ i5-6500TE processor</a>. The inference workload should run on the CPU.

# %%
#Submit job to the queue
cpu_job_id = !qsub queue_job.sh -d . -l nodes=1:tank-870:i5-6500te -F "/data/models/intel/person-detection-retail-0013/FP32/person-detection-retail-0013 CPU /data/resources/manufacturing.mp4 /data/queue_param/manufacturing.npy /output/results/manufacturing/CPU 5"

print(cpu_job_id[0])
# Out:
# zdXIRElKJxiqHNhnaek44jORhJ96Eeb1

# %% [markdown]
# #### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(cpu_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:zdXIRElKJxiqHNhnaek44jORhJ96Eeb1) are ready.
# Please wait................................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# counter : 1
# inside predict
# got processed image
# started async request
# request completed #121
# got result
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 593, xmax 869, ymin 265, ymax 937
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 972, xmax 1279, ymin 236, ymax 886
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 96, xmax 424, ymin 280, ymax 1051
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1281, xmax 1492, ymin 260, ymax 832
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1534, xmax 1773, ymin 270, ymax 745
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1428, xmax 1551, ymin 245, ymax 638
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1774, xmax 1909, ymin 269, ymax 607
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1209, xmax 1236, ymin 259, ymax 315
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1730, xmax 1837, ymin 274, ymax 573
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# got coords, image
# got num_people
# Total People in frame = 9
# Number of people in queue = {1: 1, 2: 2}
# inside #1 for
# got out text: No. of People in Queue 1 is 1
# putted text
# inside #1 for
# got out text: No. of People in Queue 2 is 2
# putted text
# written image
# counter : 2
# inside predict
# got processed image
# started async request
# request completed #121
# got result
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 593, xmax 869, ymin 264, ymax 940
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 95, xmax 425, ymin 282, ymax 1051
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 968, xmax 1278, ymin 233, ymax 889
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1281, xmax 1493, ymin 260, ymax 832
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1527, xmax 1770, ymin 272, ymax 746
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1429, xmax 1553, ymin 243, ymax 637
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1776, xmax 1910, ymin 269, ymax 606
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1730, xmax 1837, ymin 273, ymax 570
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1210, xmax 1236, ymin 259, ymax 314
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# got coords, image
# got num_people
# Total People in frame = 9
# Number of people in queue = {1: 1, 2: 2}
# inside #1 for
# got out text: No. of People in Queue 1 is 1
# putted text
# inside #1 for
# got out text: No. of People in Queue 2 is 2
# putted text
# written image
# counter : 3
# inside predict
# got processed image
# started async request
# request completed #121
# got result
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 593, xmax 869, ymin 264, ymax 940
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 95, xmax 425, ymin 283, ymax 1050
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 966, xmax 1280, ymin 234, ymax 888
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1280, xmax 1493, ymin 258, ymax 832
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1526, xmax 1771, ymin 272, ymax 744
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1427, xmax 1552, ymin 246, ymax 637
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1778, xmax 1912, ymin 269, ymax 607
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1729, xmax 1837, ymin 272, ymax 570
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1210, xmax 1237, ymin 260, ymax 315
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# got coords, image
# got num_people
# Total People in frame = 9
# Number of people in queue = {1: 1, 2: 2}
# inside #1 for
# got out text: No. of People in Queue 1 is 1
# putted text
# inside #1 for
# got out text: No. of People in Queue 2 is 2
# putted text
# written image
# counter : 4
# inside predict
# got processed image
# started async request
# request completed #121
# got result
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 593, xmax 868, ymin 264, ymax 942
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 95, xmax 424, ymin 282, ymax 1051
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 970, xmax 1287, ymin 232, ymax 884
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1279, xmax 1496, ymin 256, ymax 833
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1433, xmax 1552, ymin 239, ymax 633
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1522, xmax 1771, ymin 272, ymax 746
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1781, xmax 1913, ymin 266, ymax 608
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1729, xmax 1836, ymin 271, ymax 570
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1209, xmax 1237, ymin 259, ymax 316
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# got coords, image
# got num_people
# Total People in frame = 9
# Number of people in queue = {1: 1, 2: 2}
# inside #1 for
# got out text: No. of People in Queue 1 is 1
# putted text
# inside #1 for
# got out text: No. of People in Queue 2 is 2
# putted text
# written image
# counter : 5
# inside predict
# got processed image
# started async request
# request completed #121
# got result
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 592, xmax 868, ymin 264, ymax 948
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 94, xmax 425, ymin 282, ymax 1048
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 970, xmax 1287, ymin 233, ymax 883
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1278, xmax 1496, ymin 255, ymax 833
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1434, xmax 1551, ymin 239, ymax 632
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1521, xmax 1770, ymin 273, ymax 746
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1782, xmax 1913, ymin 267, ymax 611
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1728, xmax 1837, ymin 269, ymax 572
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# got coords, image
# got num_people
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# inside #1 for
# got out text: No. of People in Queue 1 is 1
# putted text
# inside #1 for
# got out text: No. of People in Queue 2 is 1
# putted text
# written image
# counter : 6
# inside predict
# got processed image
# started async request
# request completed #121
# got result
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 591, xmax 867, ymin 264, ymax 944
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 93, xmax 425, ymin 282, ymax 1054
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 977, xmax 1291, ymin 233, ymax 878
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1277, xmax 1498, ymin 255, ymax 833
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1434, xmax 1552, ymin 238, ymax 633
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1526, xmax 1769, ymin 272, ymax 747
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1781, xmax 1913, ymin 266, ymax 608
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1729, xmax 1837, ymin 270, ymax 571
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# got coords, image
# got num_people
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# inside #1 for
# got out text: No. of People in Queue 1 is 1
# putted text
# inside #1 for
# got out text: No. of People in Queue 2 is 1
# putted text
# written image
# counter : 7
# inside predict
# got processed image
# started async request
# request completed #121
# got result
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 591, xmax 869, ymin 265, ymax 941
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 93, xmax 425, ymin 283, ymax 1056
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 967, xmax 1290, ymin 232, ymax 877
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1278, xmax 1501, ymin 256, ymax 835
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1523, xmax 1768, ymin 272, ymax 747
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1433, xmax 1551, ymin 239, ymax 632
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1781, xmax 1913, ymin 268, ymax 608
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1729, xmax 1837, ymin 270, ymax 570
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# got coords, image
# got num_people
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# inside #1 for
# got out text: No. of People in Queue 1 is 1
# putted text
# inside #1 for
# got out text: No. of People in Queue 2 is 1
# putted text
# written image
# counter : 8
# inside predict
# got processed image
# started async request
# request completed #121
# got result
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 591, xmax 870, ymin 267, ymax 943
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 93, xmax 425, ymin 282, ymax 1054
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 973, xmax 1289, ymin 233, ymax 876
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1278, xmax 1500, ymin 255, ymax 836
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1527, xmax 1767, ymin 270, ymax 748
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1433, xmax 1550, ymin 240, ymax 633
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1780, xmax 1913, ymin 267, ymax 608
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1729, xmax 1837, ymin 270, ymax 570
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1209, xmax 1236, ymin 259, ymax 317
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# got coords, image
# got num_people
# Total People in frame = 9
# Number of people in queue = {1: 1, 2: 2}
# inside #1 for
# got out text: No. of People in Queue 1 is 1
# putted text
# inside #1 for
# got out text: No. of People in Queue 2 is 2
# putted text
# written image
# counter : 9
# inside predict
# got processed image
# started async request
# request completed #121
# got result
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 591, xmax 870, ymin 267, ymax 943
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 93, xmax 425, ymin 282, ymax 1058
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 975, xmax 1286, ymin 232, ymax 876
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1279, xmax 1498, ymin 255, ymax 836
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1534, xmax 1767, ymin 272, ymax 746
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1435, xmax 1550, ymin 242, ymax 641
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1782, xmax 1914, ymin 266, ymax 605
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1727, xmax 1839, ymin 270, ymax 573
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1208, xmax 1236, ymin 258, ymax 317
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# ...
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# got coords, image
# got num_people
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# inside #1 for
# got out text: No. of People in Queue 1 is 1
# putted text
# inside #1 for
# got out text: No. of People in Queue 2 is 1
# putted text
# written image
# counter : 274
# inside predict
# got processed image
# started async request
# request completed #121
# got result
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 590, xmax 856, ymin 258, ymax 945
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 968, xmax 1281, ymin 234, ymax 884
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 90, xmax 436, ymin 281, ymax 1058
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1278, xmax 1500, ymin 255, ymax 832
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1532, xmax 1769, ymin 277, ymax 736
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1423, xmax 1549, ymin 256, ymax 643
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# got coords, image
# got num_people
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# inside #1 for
# got out text: No. of People in Queue 1 is 1
# putted text
# inside #1 for
# got out text: No. of People in Queue 2 is 1
# putted text
# written image
# counter : 275
# inside predict
# got processed image
# started async request
# request completed #121
# got result
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 590, xmax 857, ymin 259, ymax 943
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 92, xmax 439, ymin 281, ymax 1061
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 962, xmax 1278, ymin 231, ymax 886
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1276, xmax 1497, ymin 256, ymax 831
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1534, xmax 1770, ymin 276, ymax 737
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# indide predict if
# got coordinates
# append coordinates
# inside draw output
# xmin 1420, xmax 1550, ymin 263, ymax 647
# assigned values
# drawn rectangle
# drawn output
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# got coords, image
# got num_people
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# inside #1 for
# got out text: No. of People in Queue 1 is 1
# putted text
# inside #1 for
# got out text: No. of People in Queue 2 is 1
# putted text
# written image
# counter : 276
# inside predict
# got processed image
# started async request
# request completed #121
# got result
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# inside predict for
# got coords, image
# got num_people
# Total People in frame = 0
# Number of people in queue = {1: 0, 2: 0}
# inside #1 for
# got out text: No. of People in Queue 1 is 0
# putted text
# inside #1 for
# got out text: No. of People in Queue 2 is 0
# putted text
# written image
# done f.write
# released reasources
# results/
# results/manufacturing/
# results/manufacturing/CPU/
# results/manufacturing/CPU/stats.txt
# results/manufacturing/CPU/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging.

# %%
# !cat stderr.log
# Out:
# person_detect.py:48: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Manufacturing CPU', ['results/manufacturing/cpu/output_video.mp4'])
# Out:
# <h5>Manufacturing CPU</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/manufacturing/cpu/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1.2: Submit to an Edge Compute Node with CPU and IGPU
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank* 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel® Core i5-6500TE</a>. The inference workload should run on the **Intel® HD Graphics 530** integrated GPU.

# %%
#Submit job to the queue
gpu_job_id = 

print(gpu_job_id[0])

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(gpu_job_id[0], filename='output.tgz', blocking=True)

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging.

# %%
# !cat stderr.log

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Manufacturing GPU', ['results/manufacturing/gpu/output_video.mp4'])

# %% [markdown]
# ## Step 1.3: Submit to an Edge Compute Node with a Neural Compute Stick 2
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel Core i5-6500te CPU</a>. The inference workload should run on an <a
#     href="https://software.intel.com/en-us/neural-compute-stick">Intel Neural Compute Stick 2</a> installed in this  node.

# %%
#Submit job to the queue
vpu_job_id = 

print(vpu_job_id[0])

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(vpu_job_id[0], filename='output.tgz', blocking=True)

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging.

# %%
# !cat stderr.log

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Manufacturing VPU', ['results/manufacturing/vpu/output_video.mp4'])

# %% [markdown]
# ## Step 1.4: Submit to an Edge Compute Node with IEI Mustang-F100-A10
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel Core™ i5-6500te CPU</a> . The inference workload will run on the <a href="https://www.ieiworld.com/mustang-f100/en/"> IEI Mustang-F100-A10 </a> FPGA card installed in this node.

# %%
#Submit job to the queue
fpga_job_id = 

print(fpga_job_id[0])

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(fpga_job_id[0], filename='output.tgz', blocking=True)

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging.

# %%
# !cat stderr.log

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Manufacturing FPGA', ['results/manufacturing/fpga/output_video.mp4'])

# %% [markdown]
# ***Wait!***
#
# Please wait for all the inference jobs and video rendering to complete before proceeding to the next step.
#
# ## Step 2: Assess Performance
#
# Run the cells below to compare the performance across all 4 devices. The following timings for the model are being compared across all 4 devices:
#
# - Model Loading Time
# - Average Inference Time
# - FPS

# %%
import matplotlib.pyplot as plt

device_list=['cpu', 'gpu', 'fpga', 'vpu']
inference_time=[]
fps=[]
model_load_time=[]

for device in device_list:
    with open('results/manufacturing/'+device+'/stats.txt', 'r') as f:
        inference_time.append(float(f.readline().split("\n")[0]))
        fps.append(float(f.readline().split("\n")[0]))
        model_load_time.append(float(f.readline().split("\n")[0]))

# %%
plt.bar(device_list, inference_time)
plt.xlabel("Device Used")
plt.ylabel("Total Inference Time in Seconds")
plt.show()

# %%
plt.bar(device_list, fps)
plt.xlabel("Device Used")
plt.ylabel("Frames per Second")
plt.show()

# %%
plt.bar(device_list, model_load_time)
plt.xlabel("Device Used")
plt.ylabel("Model Loading Time in Seconds")
plt.show()

# %% [markdown]
# # Step 3: Update Proposal Document
#
# Now that you've completed your hardware testing, you should go back to the proposal document and validate or update your originally proposed hardware. Once you've updated your proposal, you can move on to the next scenario.
